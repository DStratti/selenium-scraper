# %% [markdown]
# # Test Selenium
# To install selenium follow the installation guide https://selenium-python.readthedocs.io/installation.html and download the chrome drivers from Test selenium is installed and up and running correctly the these suggested sites, I will be using Chrome, please ensure you download a linux driver in addition to your platforms driver as this will be used inside our docker image https://selenium-python.readthedocs.io/installation.html#drivers
#
# TOC
# - Setup
# - Tabular Extraction
#     - [Data-Cleansing](/notebooks/Test%20Selenium.ipynb#Data-Cleansing)
# - Image Extraction
# - RPA

# %%
# Import required Selenium packages
from selenium.webdriver.chrome.webdriver import WebDriver
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options

from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By

import re
import json
import pandas as pd
import urllib.request
from datetime import datetime

# %% [markdown]
# ## Setup Chrome Driver
# Setup the chrome driver using the `selenium.webdriver.chrome.webdriver.WebDriver` as this will allow us to use the downloaded chrome driver executable. To do this we will create a service that points to the executable path using `selenium.webdriver.chrome.service.Service` (This use to be the `executable_path` parameter on the `WebDriver` but is now deprecated).
#
# Next we will also instantiate the `selenium.webdriver.chrome.options.Options` so that we can set the how elements will load on the page. We will set it to eagrer so that all HTML elements are imediately accessible and not blocked by the painting of larger elements like images etc. `Options` has many cool parameters that can let you control things like timeouts etc for a full list check out these links:
# - Options: https://www.selenium.dev/documentation/webdriver/drivers/options/
# - ChromeOptions: https://www.selenium.dev/documentation/webdriver/browsers/chrome/
#
# https://selenium-python.readthedocs.io/api.html#module-selenium.webdriver.chrome.webdriver

# %%
# Set service to exe & options for page load to eager
service = Service('./chromedriver_mac_arm64_v109') # this should be the path to your downloaded driver

options = Options()
options.page_load_strategy = 'eager'

driver = WebDriver(service=service, options=options)

# %% [markdown]
# ## Tabular Extraction

# %%
driver.get("https://au.finance.yahoo.com/gainers")

# %% [markdown]
# ### Explore & Extract
# Explore the page elements to determine how to appropriately select all the rows in the table, we then also want to extract each piece of data into the relevant feilds for later processing.

# %%
FINANCE_FEILDS = [
    "symbol",
    "name",
    "price",
    "change",
    "change %",
    "volume",
    "avg",
    "market cap",
    "pe ratio",
    "52 week"
]

# Grab rows
rows = driver.find_elements(By.CSS_SELECTOR, "div > table tbody tr")

# %%
# %%time
values = []
for el in rows:
    row = {}
    for f, v in zip(FINANCE_FEILDS, el.find_elements(By.CSS_SELECTOR, "td")):
        row[f] = v.text 
    values = [*values, row]
# Out:
# CPU times: user 83.8 ms, sys: 7.15 ms, total: 91 ms
# Wall time: 1.94 s

# %%
# print(json.dumps(values, indent=4))
values
# Out:
# [{'symbol': 'CCE.AX',
#   'name': 'Carnegie Clean Energy Limited',
#   'price': '0.0020',
#   'change': '+0.0010',
#   'change %': '+100.00%',
#   'volume': '1.61M',
#   'avg': '4.616M',
#   'market cap': '31.285M',
#   'pe ratio': 'N/A',
#   '52 week': ''},
#  {'symbol': 'ARE.AX',
#   'name': 'Argonaut Resources NL',
#   'price': '0.0030',
#   'change': '+0.0010',
#   'change %': '+50.00%',
#   'volume': '65.429M',
#   'avg': '9.588M',
#   'market cap': '19.086M',
#   'pe ratio': 'N/A',
#   '52 week': ''},
#  {'symbol': 'ANL.XA',
#   'name': 'Amani Gold Limited',
#   'price': '0.0015',
#   'change': '+0.0005',
#   'change %': '+50.00%',
#   'volume': '1.5M',
#   'avg': 'N/A',
#   'market cap': 'N/A',
#   'pe ratio': 'N/A',
#   '52 week': ''},
#  {'symbol': 'WBE.XA',
#   'name': 'Whitebark Energy Limited',
#   'price': '0.0015',
#   'change': '+0.0005',
#   'change %': '+50.00%',
#   'volume': '583,880',
#   'avg': 'N/A',
#   'market cap': 'N/A',
#   'pe ratio': '1.50',
#   '52 week': ''},
#  {'symbol': 'LNU.AX',
#   'name': 'Linius Technologies Limited',
#   'price': '0.0030',
#   'change': '+0.0010',
#   'change %': '+50.00%',
#   'volume': '755,556',
#   'avg': '6.563M',
#   'market cap': '8.938M',
#   'pe ratio': 'N/A',
#   '52 week': ''},
#  {'symbol': 'LML.XA',
#   'name': 'Lincoln Minerals Limited',
#   'price': '0.0660',
#   'change': '+0.0210',
#   'change %': '+46.67%',
#   'volume': '8.763M',
#   'avg': 'N/A',
#   'market cap': 'N/A',
#   'pe ratio': 'N/A',
#   '52 week': ''},
#  {'symbol': 'LML.AX',
#   'name': 'Lincoln Minerals Limited',
#   'price': '0.0670',
#   'change': '+0.0210',
#   'change %': '+45.65%',
#   'volume': '44.937M',
#   'avg': '597,816',
#   'market cap': '92.223M',
#   'pe ratio': 'N/A',
#   '52 week': ''},
#  {'symbol': 'ENX.XA',
#   'name': 'Enegex Limited',
#   'price': '0.0430',
#   'change': '+0.0120',
#   'change %': '+38.71%',
#   'volume': '85,000',
#   'avg': 'N/A',
#   'market cap': 'N/A',
#   'pe ratio': 'N/A',
#   '52 week': ''},
#  {'symbol': 'BME.XA',
#   'name': 'Black Mountain Energy Ltd',
#   'price': '0.0420',
#   'change': '+0.0110',
#   'change %': '+35.48%',
#   'volume': '178,331',
#   'avg': 'N/A',
#   'market cap': 'N/A',
#   'pe ratio': 'N/A',
#   '52 week': ''},
#  {'symbol': 'BME.AX',
#   'name': 'Black Mountain Energy Ltd',
#   'price': '0.0430',
#   'change': '+0.0110',
#   'change %': '+34.37%',
#   'volume': '1.203M',
#   'avg': '46,348',
#   'market cap': '10.965M',
#   'pe ratio': 'N/A',
#   '52 week': ''},
#  {'symbol': 'VPR.XA',
#   'name': 'Volt Power Group Limited',
#   'price': '0.0020',
#   'change': '+0.0005',
#   'change %': '+33.33%',
#   'volume': '2M',
#   'avg': 'N/A',
#   'market cap': 'N/A',
#   'pe ratio': 'N/A',
#   '52 week': ''},
#  {'symbol': 'PRM.XA',
#   'name': 'Prominence Energy Ltd',
#   'price': '0.0020',
#   'change': '+0.0005',
#   'change %': '+33.33%',
#   'volume': '700,000',
#   'avg': 'N/A',
#   'market cap': 'N/A',
#   'pe ratio': 'N/A',
#   '52 week': ''},
#  {'symbol': 'ROO.XA',
#   'name': 'Roots Sustainable Agricultural Technologies Ltd',
#   'price': '0.0020',
#   'change': '+0.0005',
#   'change %': '+33.33%',
#   'volume': '1.329M',
#   'avg': 'N/A',
#   'market cap': 'N/A',
#   'pe ratio': 'N/A',
#   '52 week': ''},
#  {'symbol': 'GLV.XA',
#   'name': 'Global Oil & Gas Limited',
#   'price': '0.0020',
#   'change': '+0.0005',
#   'change %': '+33.33%',
#   'volume': '17.083M',
#   'avg': 'N/A',
#   'market cap': 'N/A',
#   'pe ratio': 'N/A',
#   '52 week': ''},
#  {'symbol': 'BMO.XA',
#   'name': 'Bastion Minerals Limited',
#   'price': '0.0710',
#   'change': '+0.0160',
#   'change %': '+29.09%',
#   'volume': '438,500',
#   'avg': 'N/A',
#   'market cap': 'N/A',
#   'pe ratio': 'N/A',
#   '52 week': ''},
#  {'symbol': 'C1X.AX',
#   'name': 'Cosmos Exploration Limited',
#   'price': '0.5000',
#   'change': '+0.1100',
#   'change %': '+28.21%',
#   'volume': '5.688M',
#   'avg': '540,969',
#   'market cap': '17.5M',
#   'pe ratio': 'N/A',
#   '52 week': ''},
#  {'symbol': 'ETR.AX',
#   'name': 'Entyr Limited',
#   'price': '0.0230',
#   'change': '+0.0050',
#   'change %': '+27.78%',
#   'volume': '5.922M',
#   'avg': '1.209M',
#   'market cap': '34.677M',
#   'pe ratio': 'N/A',
#   '52 week': ''},
#  {'symbol': 'C1X.XA',
#   'name': 'COSMOSEXP FPO',
#   'price': '0.5100',
#   'change': '+0.1100',
#   'change %': '+27.50%',
#   'volume': '1.893M',
#   'avg': 'N/A',
#   'market cap': 'N/A',
#   'pe ratio': 'N/A',
#   '52 week': ''},
#  {'symbol': 'BNZ.XA',
#   'name': 'Benz Mining Corp.',
#   'price': '0.5400',
#   'change': '+0.1100',
#   'change %': '+25.58%',
#   'volume': '10,250',
#   'avg': 'N/A',
#   'market cap': 'N/A',
#   'pe ratio': 'N/A',
#   '52 week': ''},
#  {'symbol': 'SIX.XA',
#   'name': 'Sprintex Limited',
#   'price': '0.0500',
#   'change': '+0.0100',
#   'change %': '+25.00%',
#   'volume': '54,939',
#   'avg': 'N/A',
#   'market cap': 'N/A',
#   'pe ratio': 'N/A',
#   '52 week': ''},
#  {'symbol': 'BMO.AX',
#   'name': 'Bastion Minerals Limited',
#   'price': '0.0700',
#   'change': '+0.0140',
#   'change %': '+25.00%',
#   'volume': '4.852M',
#   'avg': '1.451M',
#   'market cap': '8.159M',
#   'pe ratio': 'N/A',
#   '52 week': ''},
#  {'symbol': 'PGY.AX',
#   'name': 'Pilot Energy Limited',
#   'price': '0.0200',
#   'change': '+0.0040',
#   'change %': '+25.00%',
#   'volume': '29.91M',
#   'avg': '3.258M',
#   'market cap': '15.627M',
#   'pe ratio': 'N/A',
#   '52 week': ''},
#  {'symbol': 'ADR.AX',
#   'name': 'Adherium Limited',
#   'price': '0.0050',
#   'change': '+0.0010',
#   'change %': '+25.00%',
#   'volume': '488,999',
#   'avg': '1.499M',
#   'market cap': '24.982M',
#   'pe ratio': 'N/A',
#   '52 week': ''},
#  {'symbol': 'CLZ.AX',
#   'name': 'Classic Minerals Limited',
#   'price': '0.0100',
#   'change': '+0.0020',
#   'change %': '+25.00%',
#   'volume': '7.243M',
#   'avg': '6.121M',
#   'market cap': '8.833M',
#   'pe ratio': 'N/A',
#   '52 week': ''},
#  {'symbol': 'PGY.XA',
#   'name': 'Pilot Energy Limited',
#   'price': '0.0200',
#   'change': '+0.0040',
#   'change %': '+25.00%',
#   'volume': '9.128M',
#   'avg': 'N/A',
#   'market cap': 'N/A',
#   'pe ratio': 'N/A',
#   '52 week': ''}]

# %%
# %%time
values = [{f: v.text for f,v in zip(FINANCE_FEILDS, el.find_elements(By.CSS_SELECTOR, "td"))} for el in rows]
# Out:
# CPU times: user 65.7 ms, sys: 5.84 ms, total: 71.5 ms
# Wall time: 798 ms

# %%
driver.close()
print(json.dumps(values, indent=4))
# Out:
# [
#     {
#         "symbol": "CCE.AX",
#         "name": "Carnegie Clean Energy Limited",
#         "price": "0.0020",
#         "change": "+0.0010",
#         "change %": "+100.00%",
#         "volume": "1.61M",
#         "avg": "4.616M",
#         "market cap": "31.285M",
#         "pe ratio": "N/A",
#         "52 week": ""
#     },
#     {
#         "symbol": "ARE.AX",
#         "name": "Argonaut Resources NL",
#         "price": "0.0030",
#         "change": "+0.0010",
#         "change %": "+50.00%",
#         "volume": "65.429M",
#         "avg": "9.588M",
#         "market cap": "19.086M",
#         "pe ratio": "N/A",
#         "52 week": ""
#     },
#     {
#         "symbol": "ANL.XA",
#         "name": "Amani Gold Limited",
#         "price": "0.0015",
#         "change": "+0.0005",
#         "change %": "+50.00%",
#         "volume": "1.5M",
#         "avg": "N/A",
#         "market cap": "N/A",
#         "pe ratio": "N/A",
#         "52 week": ""
#     },
#     {
#         "symbol": "WBE.XA",
#         "name": "Whitebark Energy Limited",
#         "price": "0.0015",
#         "change": "+0.0005",
#         "change %": "+50.00%",
#         "volume": "583,880",
#         "avg": "N/A",
#         "market cap": "N/A",
#         "pe ratio": "1.50",
#         "52 week": ""
#     },
#     {
#         "symbol": "LNU.AX",
#         "name": "Linius Technologies Limited",
#         "price": "0.0030",
#         "change": "+0.0010",
#         "change %": "+50.00%",
#         "volume": "755,556",
#         "avg": "6.563M",
#         "market cap": "8.938M",
#         "pe ratio": "N/A",
#         "52 week": ""
#     },
#     {
#         "symbol": "LML.XA",
#         "name": "Lincoln Minerals Limited",
#         "price": "0.0660",
#         "change": "+0.0210",
#         "change %": "+46.67%",
#         "volume": "8.763M",
#         "avg": "N/A",
#         "market cap": "N/A",
#         "pe ratio": "N/A",
#         "52 week": ""
#     },
#     {
#         "symbol": "LML.AX",
#         "name": "Lincoln Minerals Limited",
#         "price": "0.0670",
#         "change": "+0.0210",
#         "change %": "+45.65%",
#         "volume": "44.937M",
#         "avg": "597,816",
#         "market cap": "92.223M",
#         "pe ratio": "N/A",
#         "52 week": ""
#     },
#     {
#         "symbol": "ENX.XA",
#         "name": "Enegex Limited",
#         "price": "0.0430",
#         "change": "+0.0120",
#         "change %": "+38.71%",
#         "volume": "85,000",
#         "avg": "N/A",
#         "market cap": "N/A",
#         "pe ratio": "N/A",
#         "52 week": ""
#     },
#     {
#         "symbol": "BME.XA",
#         "name": "Black Mountain Energy Ltd",
#         "price": "0.0420",
#         "change": "+0.0110",
#         "change %": "+35.48%",
#         "volume": "178,331",
#         "avg": "N/A",
#         "market cap": "N/A",
#         "pe ratio": "N/A",
#         "52 week": ""
#     },
#     {
#         "symbol": "BME.AX",
#         "name": "Black Mountain Energy Ltd",
#         "price": "0.0430",
#         "change": "+0.0110",
#         "change %": "+34.37%",
#         "volume": "1.203M",
#         "avg": "46,348",
#         "market cap": "10.965M",
#         "pe ratio": "N/A",
#         "52 week": ""
#     },
#     {
#         "symbol": "VPR.XA",
#         "name": "Volt Power Group Limited",
#         "price": "0.0020",
#         "change": "+0.0005",
#         "change %": "+33.33%",
#         "volume": "2M",
#         "avg": "N/A",
#         "market cap": "N/A",
#         "pe ratio": "N/A",
#         "52 week": ""
#     },
#     {
#         "symbol": "PRM.XA",
#         "name": "Prominence Energy Ltd",
#         "price": "0.0020",
#         "change": "+0.0005",
#         "change %": "+33.33%",
#         "volume": "700,000",
#         "avg": "N/A",
#         "market cap": "N/A",
#         "pe ratio": "N/A",
#         "52 week": ""
#     },
#     {
#         "symbol": "ROO.XA",
#         "name": "Roots Sustainable Agricultural Technologies Ltd",
#         "price": "0.0020",
#         "change": "+0.0005",
#         "change %": "+33.33%",
#         "volume": "1.329M",
#         "avg": "N/A",
#         "market cap": "N/A",
#         "pe ratio": "N/A",
#         "52 week": ""
#     },
#     {
#         "symbol": "GLV.XA",
#         "name": "Global Oil & Gas Limited",
#         "price": "0.0020",
#         "change": "+0.0005",
#         "change %": "+33.33%",
#         "volume": "17.083M",
#         "avg": "N/A",
#         "market cap": "N/A",
#         "pe ratio": "N/A",
#         "52 week": ""
#     },
#     {
#         "symbol": "BMO.XA",
#         "name": "Bastion Minerals Limited",
#         "price": "0.0710",
#         "change": "+0.0160",
#         "change %": "+29.09%",
#         "volume": "438,500",
#         "avg": "N/A",
#         "market cap": "N/A",
#         "pe ratio": "N/A",
#         "52 week": ""
#     },
#     {
#         "symbol": "C1X.AX",
#         "name": "Cosmos Exploration Limited",
#         "price": "0.5000",
#         "change": "+0.1100",
#         "change %": "+28.21%",
#         "volume": "5.688M",
#         "avg": "540,969",
#         "market cap": "17.5M",
#         "pe ratio": "N/A",
#         "52 week": ""
#     },
#     {
#         "symbol": "ETR.AX",
#         "name": "Entyr Limited",
#         "price": "0.0230",
#         "change": "+0.0050",
#         "change %": "+27.78%",
#         "volume": "5.922M",
#         "avg": "1.209M",
#         "market cap": "34.677M",
#         "pe ratio": "N/A",
#         "52 week": ""
#     },
#     {
#         "symbol": "C1X.XA",
#         "name": "COSMOSEXP FPO",
#         "price": "0.5100",
#         "change": "+0.1100",
#         "change %": "+27.50%",
#         "volume": "1.893M",
#         "avg": "N/A",
#         "market cap": "N/A",
#         "pe ratio": "N/A",
#         "52 week": ""
#     },
#     {
#         "symbol": "BNZ.XA",
#         "name": "Benz Mining Corp.",
#         "price": "0.5400",
#         "change": "+0.1100",
#         "change %": "+25.58%",
#         "volume": "10,250",
#         "avg": "N/A",
#         "market cap": "N/A",
#         "pe ratio": "N/A",
#         "52 week": ""
#     },
#     {
#         "symbol": "SIX.XA",
#         "name": "Sprintex Limited",
#         "price": "0.0500",
#         "change": "+0.0100",
#         "change %": "+25.00%",
#         "volume": "54,939",
#         "avg": "N/A",
#         "market cap": "N/A",
#         "pe ratio": "N/A",
#         "52 week": ""
#     },
#     {
#         "symbol": "BMO.AX",
#         "name": "Bastion Minerals Limited",
#         "price": "0.0700",
#         "change": "+0.0140",
#         "change %": "+25.00%",
#         "volume": "4.852M",
#         "avg": "1.451M",
#         "market cap": "8.159M",
#         "pe ratio": "N/A",
#         "52 week": ""
#     },
#     {
#         "symbol": "PGY.AX",
#         "name": "Pilot Energy Limited",
#         "price": "0.0200",
#         "change": "+0.0040",
#         "change %": "+25.00%",
#         "volume": "29.91M",
#         "avg": "3.258M",
#         "market cap": "15.627M",
#         "pe ratio": "N/A",
#         "52 week": ""
#     },
#     {
#         "symbol": "ADR.AX",
#         "name": "Adherium Limited",
#         "price": "0.0050",
#         "change": "+0.0010",
#         "change %": "+25.00%",
#         "volume": "488,999",
#         "avg": "1.499M",
#         "market cap": "24.982M",
#         "pe ratio": "N/A",
#         "52 week": ""
#     },
#     {
#         "symbol": "CLZ.AX",
#         "name": "Classic Minerals Limited",
#         "price": "0.0100",
#         "change": "+0.0020",
#         "change %": "+25.00%",
#         "volume": "7.243M",
#         "avg": "6.121M",
#         "market cap": "8.833M",
#         "pe ratio": "N/A",
#         "52 week": ""
#     },
#     {
#         "symbol": "PGY.XA",
#         "name": "Pilot Energy Limited",
#         "price": "0.0200",
#         "change": "+0.0040",
#         "change %": "+25.00%",
#         "volume": "9.128M",
#         "avg": "N/A",
#         "market cap": "N/A",
#         "pe ratio": "N/A",
#         "52 week": ""
#     }
# ]

# %%
gainers = pd.DataFrame(values)
gainers
# Out:
#     symbol                                             name   price   change  \
# 0   CCE.AX                    Carnegie Clean Energy Limited  0.0020  +0.0010
# 1   ARE.AX                            Argonaut Resources NL  0.0030  +0.0010
# 2   ANL.XA                               Amani Gold Limited  0.0015  +0.0005
# 3   WBE.XA                         Whitebark Energy Limited  0.0015  +0.0005
# 4   LNU.AX                      Linius Technologies Limited  0.0030  +0.0010
# 5   LML.XA                         Lincoln Minerals Limited  0.0660  +0.0210
# 6   LML.AX                         Lincoln Minerals Limited  0.0670  +0.0210
# 7   ENX.XA                                   Enegex Limited  0.0430  +0.0120
# 8   BME.XA                        Black Mountain Energy Ltd  0.0420  +0.0110
# 9   BME.AX                        Black Mountain Energy Ltd  0.0430  +0.0110
# 10  VPR.XA                         Volt Power Group Limited  0.0020  +0.0005
# 11  PRM.XA                            Prominence Energy Ltd  0.0020  +0.0005
# 12  ROO.XA  Roots Sustainable Agricultural Technologies Ltd  0.0020  +0.0005
# 13  GLV.XA                         Global Oil & Gas Limited  0.0020  +0.0005
# 14  BMO.XA                         Bastion Minerals Limited  0.0710  +0.0160
# 15  C1X.AX                       Cosmos Exploration Limited  0.5000  +0.1100
# 16  ETR.AX                                    Entyr Limited  0.0230  +0.0050
# 17  C1X.XA                                    COSMOSEXP FPO  0.5100  +0.1100
# 18  BNZ.XA                                Benz Mining Corp.  0.5400  +0.1100
# 19  SIX.XA                                 Sprintex Limited  0.0500  +0.0100
# 20  BMO.AX                         Bastion Minerals Limited  0.0700  +0.0140
# 21  PGY.AX                             Pilot Energy Limited  0.0200  +0.0040
# 22  ADR.AX                                 Adherium Limited  0.0050  +0.0010
# 23  CLZ.AX                         Classic Minerals Limited  0.0100  +0.0020
# 24  PGY.XA                             Pilot Energy Limited  0.0200  +0.0040
#
#     change %   volume      avg market cap pe ratio 52 week
# 0   +100.00%    1.61M   4.616M    31.285M      N/A
# 1    +50.00%  65.429M   9.588M    19.086M      N/A
# 2    +50.00%     1.5M      N/A        N/A      N/A
# 3    +50.00%  583,880      N/A        N/A     1.50
# 4    +50.00%  755,556   6.563M     8.938M      N/A
# 5    +46.67%   8.763M      N/A        N/A      N/A
# 6    +45.65%  44.937M  597,816    92.223M      N/A
# 7    +38.71%   85,000      N/A        N/A      N/A
# 8    +35.48%  178,331      N/A        N/A      N/A
# 9    +34.37%   1.203M   46,348    10.965M      N/A
# 10   +33.33%       2M      N/A        N/A      N/A
# 11   +33.33%  700,000      N/A        N/A      N/A
# 12   +33.33%   1.329M      N/A        N/A      N/A
# 13   +33.33%  17.083M      N/A        N/A      N/A
# 14   +29.09%  438,500      N/A        N/A      N/A
# 15   +28.21%   5.688M  540,969      17.5M      N/A
# 16   +27.78%   5.922M   1.209M    34.677M      N/A
# 17   +27.50%   1.893M      N/A        N/A      N/A
# 18   +25.58%   10,250      N/A        N/A      N/A
# 19   +25.00%   54,939      N/A        N/A      N/A
# 20   +25.00%   4.852M   1.451M     8.159M      N/A
# 21   +25.00%   29.91M   3.258M    15.627M      N/A
# 22   +25.00%  488,999   1.499M    24.982M      N/A
# 23   +25.00%   7.243M   6.121M     8.833M      N/A
# 24   +25.00%   9.128M      N/A        N/A      N/A

# %% [markdown]
# ### Data Cleansing
# Remove nuerical formating and cast colums to the correct data type

# %%
def numeric_conversion(v: any) -> float:
    '''
    Remove the string formating of the numercal data. 
    This includes the following characters: +,%M
    Additionally it replaces `N/A` with None
    
    v : any
        The value to transform, it is expected to be a string or castable to one
    
    returns : float 
        The numeric value represented as a float
    '''
    v = re.sub(r"(?i)(\+|,|%)", '', v)
       
    if 'M' in v:
        v = v.replace('M', '')
        v = float(v) * 1_000_000
    
    elif 'N/A' == v:
        v = None
        
    return v

# %%
gainers['price'] = gainers['price'].apply(numeric_conversion)
gainers['change'] = gainers['change'].apply(numeric_conversion)
gainers['change %'] = gainers['change %'].apply(numeric_conversion)
gainers['volume'] = gainers['volume'].apply(numeric_conversion)
gainers['avg'] = gainers['avg'].apply(numeric_conversion)
gainers['market cap'] = gainers['market cap'].apply(numeric_conversion)
gainers['pe ratio'] = gainers['pe ratio'].apply(numeric_conversion)

# Sketchy


try:
    del gainers['52 week']
except Exception as e:
    print(e)

gainers
# Out:
#     symbol                                             name   price  change  \
# 0   CCE.AX                    Carnegie Clean Energy Limited  0.0020  0.0010
# 1   ARE.AX                            Argonaut Resources NL  0.0030  0.0010
# 2   ANL.XA                               Amani Gold Limited  0.0015  0.0005
# 3   WBE.XA                         Whitebark Energy Limited  0.0015  0.0005
# 4   LNU.AX                      Linius Technologies Limited  0.0030  0.0010
# 5   LML.XA                         Lincoln Minerals Limited  0.0660  0.0210
# 6   LML.AX                         Lincoln Minerals Limited  0.0670  0.0210
# 7   ENX.XA                                   Enegex Limited  0.0430  0.0120
# 8   BME.XA                        Black Mountain Energy Ltd  0.0420  0.0110
# 9   BME.AX                        Black Mountain Energy Ltd  0.0430  0.0110
# 10  VPR.XA                         Volt Power Group Limited  0.0020  0.0005
# 11  PRM.XA                            Prominence Energy Ltd  0.0020  0.0005
# 12  ROO.XA  Roots Sustainable Agricultural Technologies Ltd  0.0020  0.0005
# 13  GLV.XA                         Global Oil & Gas Limited  0.0020  0.0005
# 14  BMO.XA                         Bastion Minerals Limited  0.0710  0.0160
# 15  C1X.AX                       Cosmos Exploration Limited  0.5000  0.1100
# 16  ETR.AX                                    Entyr Limited  0.0230  0.0050
# 17  C1X.XA                                    COSMOSEXP FPO  0.5100  0.1100
# 18  BNZ.XA                                Benz Mining Corp.  0.5400  0.1100
# 19  SIX.XA                                 Sprintex Limited  0.0500  0.0100
# 20  BMO.AX                         Bastion Minerals Limited  0.0700  0.0140
# 21  PGY.AX                             Pilot Energy Limited  0.0200  0.0040
# 22  ADR.AX                                 Adherium Limited  0.0050  0.0010
# 23  CLZ.AX                         Classic Minerals Limited  0.0100  0.0020
# 24  PGY.XA                             Pilot Energy Limited  0.0200  0.0040
#
#    change %      volume        avg  market cap pe ratio
# 0    100.00   1610000.0  4616000.0  31285000.0     None
# 1     50.00  65429000.0  9588000.0  19086000.0     None
# 2     50.00   1500000.0       None         NaN     None
# 3     50.00      583880       None         NaN     1.50
# 4     50.00      755556  6563000.0   8938000.0     None
# 5     46.67   8763000.0       None         NaN     None
# 6     45.65  44937000.0     597816  92223000.0     None
# 7     38.71       85000       None         NaN     None
# 8     35.48      178331       None         NaN     None
# 9     34.37   1203000.0      46348  10965000.0     None
# 10    33.33   2000000.0       None         NaN     None
# 11    33.33      700000       None         NaN     None
# 12    33.33   1329000.0       None         NaN     None
# 13    33.33  17083000.0       None         NaN     None
# 14    29.09      438500       None         NaN     None
# 15    28.21   5688000.0     540969  17500000.0     None
# 16    27.78   5922000.0  1209000.0  34677000.0     None
# 17    27.50   1893000.0       None         NaN     None
# 18    25.58       10250       None         NaN     None
# 19    25.00       54939       None         NaN     None
# 20    25.00   4852000.0  1451000.0   8159000.0     None
# 21    25.00  29910000.0  3258000.0  15627000.0     None
# 22    25.00      488999  1499000.0  24982000.0     None
# 23    25.00   7243000.0  6121000.0   8833000.0     None
# 24    25.00   9128000.0       None         NaN     None

# %%
### Save To C.S.V

datetime.today().strftime("%Y_%m_%d")
# Out:
# '2023_01_30'

# %%
gainers.to_csv('./data/tabular/gainers_%s.csv' % datetime.today().strftime("%Y_%m_%d"), index=False)

# %% [markdown]
# ## Image Extraction

# %%
browser = WebDriver(service=service, options=options)
browser.get("http://books.toscrape.com/")

# %%
raw_books = browser.find_elements(By.CSS_SELECTOR, "article.product_pod")
raw_books
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="3b0d2c8dde161329f73c7628563f0921", element="8a569879-2a3f-485d-952b-e56ca0dff926")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="3b0d2c8dde161329f73c7628563f0921", element="9df15391-4f03-4cfb-a083-d9a747c8428c")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="3b0d2c8dde161329f73c7628563f0921", element="255f3b36-ba0c-4990-bc81-4792bdf6cc0b")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="3b0d2c8dde161329f73c7628563f0921", element="46a9dd14-8a90-43e5-b075-f40c6f50c9b2")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="3b0d2c8dde161329f73c7628563f0921", element="e4d3bd10-49f9-474f-ae38-915069c6eb57")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="3b0d2c8dde161329f73c7628563f0921", element="31bb4177-231d-4d84-81d9-a73e672a9bf6")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="3b0d2c8dde161329f73c7628563f0921", element="6740d6dd-4d41-498d-a737-706bfc8b14f9")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="3b0d2c8dde161329f73c7628563f0921", element="1970c1cd-f780-4af1-b5db-53346a4c654f")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="3b0d2c8dde161329f73c7628563f0921", element="65146a94-348b-4c84-bdfd-7f2287eb2570")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="3b0d2c8dde161329f73c7628563f0921", element="7233fb17-fe34-4836-8830-7d5b2abb32c8")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="3b0d2c8dde161329f73c7628563f0921", element="2e7d29b3-846a-405e-9615-465c48d87b99")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="3b0d2c8dde161329f73c7628563f0921", element="1f60d2c1-3883-48ca-80e2-9ee1c56491a0")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="3b0d2c8dde161329f73c7628563f0921", element="db3b1df0-8722-4ad6-96a7-18780c8c86d1")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="3b0d2c8dde161329f73c7628563f0921", element="18469576-e510-4402-adc0-680572975181")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="3b0d2c8dde161329f73c7628563f0921", element="8e1344e5-2f1b-4dc7-b3e4-533066f7fef7")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="3b0d2c8dde161329f73c7628563f0921", element="b3e3d526-64ae-4421-8b47-8d480f6baa80")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="3b0d2c8dde161329f73c7628563f0921", element="faa895c3-d245-4855-910f-f20691ba6174")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="3b0d2c8dde161329f73c7628563f0921", element="13b3047c-f606-4dcb-99a8-394a660d9cf0")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="3b0d2c8dde161329f73c7628563f0921", element="e05503a3-cb55-42cb-a827-65d775606b8f")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="3b0d2c8dde161329f73c7628563f0921", element="1c1cac97-926c-4cef-a3c7-d47c08c8b17b")>]

# %%
BOOK_FEILDS = [
    "link",
    "image",
    "title",
    "rating",
    "price"
]

def extract_rawbooks(book: any) -> dict:
    '''
    Extract the data that represents a book from the raw HTML elements
    This includes the image link, image, title, rating & price
    
    book : selenium.webdriver.remote.webelement.WebElement
        The HTML wrapper containing all book elements
        
    returns : dict
        The book data represented as a dictionary
    '''
    
    return {
        **extract_image_link(book),
        **extract_rating(book),
        **extract_price(book)
    }
        

def extract_image_link(book: any) -> dict:
    '''
    Extract the books cover image and URL
    
    book : selenium.webdriver.remote.webelement.WebElement
        The HTML elements containing all book elements
        
    returns : dict
        The star rating
    '''
    link = book.find_element(By.CSS_SELECTOR, "div.image_container a").get_attribute("href")
    image = book.find_element(By.CSS_SELECTOR, "div.image_container img")
    
    img_url = image.get_attribute("src")
    
    return {
        "link": link,
        "image": image
    }
    

def extract_rating(book: any) -> dict:
    '''
    Extract the rating out of 5 stars based on the 
    CSS coloring of the star elements
    
    book : selenium.webdriver.remote.webelement.WebElement
        The HTML elements containing all book elements
        
    returns : dict
        The star rating
    '''
    yellow_rbga = 'rgba(230, 206, 49, 1)'
    
    stars = book.find_elements(By.CSS_SELECTOR, "i.icon-star")
    rating = [star.value_of_css_property("color") for star in stars].count(yellow_rbga)
    
    return {
        "stars": rating,
        "rating": round((rating / len(stars)) * 100, 2)
    }


def clean_price(v: any) -> float:
    '''
    Ensure price is a float and remove any formating, 
    this extends our earlier function see: `numeric_conversion`
    
    v : any
        The value to transform, it is expected to be a string or castable to one
    
    returns : float 
        The numeric value represented as a float
    '''
    v = re.sub(r"(?i)(£)", '', str(v))
    return numeric_conversion(v)
    

def extract_price(book: any) -> dict:
    '''
    Extract the books price and availability
    
    book : selenium.webdriver.remote.webelement.WebElement
        The HTML elements containing all book elements
        
    returns : dict
        The star rating
    '''
    available = "In stock"
    price = book.find_element(By.CSS_SELECTOR, 'div.product_price p.price_color').text
    price = clean_price(price)
    
    status = book.find_element(By.CSS_SELECTOR, 'div.product_price p.availability').text
    
    availability = status == available
    
    print(price, status, availability)
    return {
        "price": price,
        "status": status,
        "is_availble": availability
    }

# %%
def extract_rawbooks(book: any) -> dict:
    '''
    Extract the data that represents a book from the raw HTML elements
    This includes the image link, image, title, rating & price
    
    book : selenium.webdriver.remote.webelement.WebElement
        The HTML wrapper containing all book elements
        
    returns : dict
        The book data represented as a dictionary
    '''
    yellow_rbga = 'rgba(230, 206, 49, 1)'
    available = "In stock"
    
    # Extract URL, Title & Image link
    link = book.find_element(By.CSS_SELECTOR, "div.image_container a").get_attribute("href")
    title = book.find_element(By.CSS_SELECTOR, "h3 a").text
    image = book.find_element(By.CSS_SELECTOR, "div.image_container img")
    
    img_url = image.get_attribute("src")
    
    # Extract Stars & Rating
    stars = book.find_elements(By.CSS_SELECTOR, "i.icon-star")
    rating = [star.value_of_css_property("color") for star in stars].count(yellow_rbga)
    
    # Extract Price & Status
    price = book.find_element(By.CSS_SELECTOR, 'div.product_price p.price_color').text
    status = book.find_element(By.CSS_SELECTOR, 'div.product_price p.availability').text
    
    # Clean Price & Store image
    price = clean_price(price)
    availability = status == available
    
    # Save book cover image to local
    with open(f'./data/img/{title}.png', 'wb') as file:
        file.write(image.screenshot_as_png)
        file.close()
        
    return {
        "title": title,
        "link": link,
        "image": img_url,
        "stars": rating,
        "rating": round((rating / len(stars)) * 100, 2),
        "price": price,
        "status": status,
        "is_availble": availability
    }

# %%
clean_books = [extract_rawbooks(rb) for rb in raw_books]
clean_books
# Out:
# [{'title': 'A Light in the ...',
#   'link': 'http://books.toscrape.com/catalogue/a-light-in-the-attic_1000/index.html',
#   'image': 'http://books.toscrape.com/media/cache/2c/da/2cdad67c44b002e7ead0cc35693c0e8b.jpg',
#   'stars': 3,
#   'rating': 60.0,
#   'price': '51.77',
#   'status': 'In stock',
#   'is_availble': True},
#  {'title': 'Tipping the Velvet',
#   'link': 'http://books.toscrape.com/catalogue/tipping-the-velvet_999/index.html',
#   'image': 'http://books.toscrape.com/media/cache/26/0c/260c6ae16bce31c8f8c95daddd9f4a1c.jpg',
#   'stars': 1,
#   'rating': 20.0,
#   'price': '53.74',
#   'status': 'In stock',
#   'is_availble': True},
#  {'title': 'Soumission',
#   'link': 'http://books.toscrape.com/catalogue/soumission_998/index.html',
#   'image': 'http://books.toscrape.com/media/cache/3e/ef/3eef99c9d9adef34639f510662022830.jpg',
#   'stars': 1,
#   'rating': 20.0,
#   'price': '50.10',
#   'status': 'In stock',
#   'is_availble': True},
#  {'title': 'Sharp Objects',
#   'link': 'http://books.toscrape.com/catalogue/sharp-objects_997/index.html',
#   'image': 'http://books.toscrape.com/media/cache/32/51/3251cf3a3412f53f339e42cac2134093.jpg',
#   'stars': 4,
#   'rating': 80.0,
#   'price': '47.82',
#   'status': 'In stock',
#   'is_availble': True},
#  {'title': 'Sapiens: A Brief History ...',
#   'link': 'http://books.toscrape.com/catalogue/sapiens-a-brief-history-of-humankind_996/index.html',
#   'image': 'http://books.toscrape.com/media/cache/be/a5/bea5697f2534a2f86a3ef27b5a8c12a6.jpg',
#   'stars': 5,
#   'rating': 100.0,
#   'price': '54.23',
#   'status': 'In stock',
#   'is_availble': True},
#  {'title': 'The Requiem Red',
#   'link': 'http://books.toscrape.com/catalogue/the-requiem-red_995/index.html',
#   'image': 'http://books.toscrape.com/media/cache/68/33/68339b4c9bc034267e1da611ab3b34f8.jpg',
#   'stars': 1,
#   'rating': 20.0,
#   'price': '22.65',
#   'status': 'In stock',
#   'is_availble': True},
#  {'title': 'The Dirty Little Secrets ...',
#   'link': 'http://books.toscrape.com/catalogue/the-dirty-little-secrets-of-getting-your-dream-job_994/index.html',
#   'image': 'http://books.toscrape.com/media/cache/92/27/92274a95b7c251fea59a2b8a78275ab4.jpg',
#   'stars': 4,
#   'rating': 80.0,
#   'price': '33.34',
#   'status': 'In stock',
#   'is_availble': True},
#  {'title': 'The Coming Woman: A ...',
#   'link': 'http://books.toscrape.com/catalogue/the-coming-woman-a-novel-based-on-the-life-of-the-infamous-feminist-victoria-woodhull_993/index.html',
#   'image': 'http://books.toscrape.com/media/cache/3d/54/3d54940e57e662c4dd1f3ff00c78cc64.jpg',
#   'stars': 3,
#   'rating': 60.0,
#   'price': '17.93',
#   'status': 'In stock',
#   'is_availble': True},
#  {'title': 'The Boys in the ...',
#   'link': 'http://books.toscrape.com/catalogue/the-boys-in-the-boat-nine-americans-and-their-epic-quest-for-gold-at-the-1936-berlin-olympics_992/index.html',
#   'image': 'http://books.toscrape.com/media/cache/66/88/66883b91f6804b2323c8369331cb7dd1.jpg',
#   'stars': 4,
#   'rating': 80.0,
#   'price': '22.60',
#   'status': 'In stock',
#   'is_availble': True},
#  {'title': 'The Black Maria',
#   'link': 'http://books.toscrape.com/catalogue/the-black-maria_991/index.html',
#   'image': 'http://books.toscrape.com/media/cache/58/46/5846057e28022268153beff6d352b06c.jpg',
#   'stars': 1,
#   'rating': 20.0,
#   'price': '52.15',
#   'status': 'In stock',
#   'is_availble': True},
#  {'title': 'Starving Hearts (Triangular Trade ...',
#   'link': 'http://books.toscrape.com/catalogue/starving-hearts-triangular-trade-trilogy-1_990/index.html',
#   'image': 'http://books.toscrape.com/media/cache/be/f4/bef44da28c98f905a3ebec0b87be8530.jpg',
#   'stars': 2,
#   'rating': 40.0,
#   'price': '13.99',
#   'status': 'In stock',
#   'is_availble': True},
#  {'title': "Shakespeare's Sonnets",
#   'link': 'http://books.toscrape.com/catalogue/shakespeares-sonnets_989/index.html',
#   'image': 'http://books.toscrape.com/media/cache/10/48/1048f63d3b5061cd2f424d20b3f9b666.jpg',
#   'stars': 4,
#   'rating': 80.0,
#   'price': '20.66',
#   'status': 'In stock',
#   'is_availble': True},
#  {'title': 'Set Me Free',
#   'link': 'http://books.toscrape.com/catalogue/set-me-free_988/index.html',
#   'image': 'http://books.toscrape.com/media/cache/5b/88/5b88c52633f53cacf162c15f4f823153.jpg',
#   'stars': 5,
#   'rating': 100.0,
#   'price': '17.46',
#   'status': 'In stock',
#   'is_availble': True},
#  {'title': "Scott Pilgrim's Precious Little ...",
#   'link': 'http://books.toscrape.com/catalogue/scott-pilgrims-precious-little-life-scott-pilgrim-1_987/index.html',
#   'image': 'http://books.toscrape.com/media/cache/94/b1/94b1b8b244bce9677c2f29ccc890d4d2.jpg',
#   'stars': 5,
#   'rating': 100.0,
#   'price': '52.29',
#   'status': 'In stock',
#   'is_availble': True},
#  {'title': 'Rip it Up and ...',
#   'link': 'http://books.toscrape.com/catalogue/rip-it-up-and-start-again_986/index.html',
#   'image': 'http://books.toscrape.com/media/cache/81/c4/81c4a973364e17d01f217e1188253d5e.jpg',
#   'stars': 5,
#   'rating': 100.0,
#   'price': '35.02',
#   'status': 'In stock',
#   'is_availble': True},
#  {'title': 'Our Band Could Be ...',
#   'link': 'http://books.toscrape.com/catalogue/our-band-could-be-your-life-scenes-from-the-american-indie-underground-1981-1991_985/index.html',
#   'image': 'http://books.toscrape.com/media/cache/54/60/54607fe8945897cdcced0044103b10b6.jpg',
#   'stars': 3,
#   'rating': 60.0,
#   'price': '57.25',
#   'status': 'In stock',
#   'is_availble': True},
#  {'title': 'Olio',
#   'link': 'http://books.toscrape.com/catalogue/olio_984/index.html',
#   'image': 'http://books.toscrape.com/media/cache/55/33/553310a7162dfbc2c6d19a84da0df9e1.jpg',
#   'stars': 1,
#   'rating': 20.0,
#   'price': '23.88',
#   'status': 'In stock',
#   'is_availble': True},
#  {'title': 'Mesaerion: The Best Science ...',
#   'link': 'http://books.toscrape.com/catalogue/mesaerion-the-best-science-fiction-stories-1800-1849_983/index.html',
#   'image': 'http://books.toscrape.com/media/cache/09/a3/09a3aef48557576e1a85ba7efea8ecb7.jpg',
#   'stars': 1,
#   'rating': 20.0,
#   'price': '37.59',
#   'status': 'In stock',
#   'is_availble': True},
#  {'title': 'Libertarianism for Beginners',
#   'link': 'http://books.toscrape.com/catalogue/libertarianism-for-beginners_982/index.html',
#   'image': 'http://books.toscrape.com/media/cache/0b/bc/0bbcd0a6f4bcd81ccb1049a52736406e.jpg',
#   'stars': 2,
#   'rating': 40.0,
#   'price': '51.33',
#   'status': 'In stock',
#   'is_availble': True},
#  {'title': "It's Only the Himalayas",
#   'link': 'http://books.toscrape.com/catalogue/its-only-the-himalayas_981/index.html',
#   'image': 'http://books.toscrape.com/media/cache/27/a5/27a53d0bb95bdd88288eaf66c9230d7e.jpg',
#   'stars': 2,
#   'rating': 40.0,
#   'price': '45.17',
#   'status': 'In stock',
#   'is_availble': True}]

# %%
books = pd.DataFrame(clean_books)
books
# Out:
#                                     title  \
# 0                      A Light in the ...
# 1                      Tipping the Velvet
# 2                              Soumission
# 3                           Sharp Objects
# 4            Sapiens: A Brief History ...
# 5                         The Requiem Red
# 6            The Dirty Little Secrets ...
# 7                 The Coming Woman: A ...
# 8                     The Boys in the ...
# 9                         The Black Maria
# 10  Starving Hearts (Triangular Trade ...
# 11                  Shakespeare's Sonnets
# 12                            Set Me Free
# 13    Scott Pilgrim's Precious Little ...
# 14                      Rip it Up and ...
# 15                  Our Band Could Be ...
# 16                                   Olio
# 17        Mesaerion: The Best Science ...
# 18           Libertarianism for Beginners
# 19                It's Only the Himalayas
#
#                                                  link  \
# 0   http://books.toscrape.com/catalogue/a-light-in...
# 1   http://books.toscrape.com/catalogue/tipping-th...
# 2   http://books.toscrape.com/catalogue/soumission...
# 3   http://books.toscrape.com/catalogue/sharp-obje...
# 4   http://books.toscrape.com/catalogue/sapiens-a-...
# 5   http://books.toscrape.com/catalogue/the-requie...
# 6   http://books.toscrape.com/catalogue/the-dirty-...
# 7   http://books.toscrape.com/catalogue/the-coming...
# 8   http://books.toscrape.com/catalogue/the-boys-i...
# 9   http://books.toscrape.com/catalogue/the-black-...
# 10  http://books.toscrape.com/catalogue/starving-h...
# 11  http://books.toscrape.com/catalogue/shakespear...
# 12  http://books.toscrape.com/catalogue/set-me-fre...
# 13  http://books.toscrape.com/catalogue/scott-pilg...
# 14  http://books.toscrape.com/catalogue/rip-it-up-...
# 15  http://books.toscrape.com/catalogue/our-band-c...
# 16  http://books.toscrape.com/catalogue/olio_984/i...
# 17  http://books.toscrape.com/catalogue/mesaerion-...
# 18  http://books.toscrape.com/catalogue/libertaria...
# 19  http://books.toscrape.com/catalogue/its-only-t...
#
#                                                 image  stars  rating  price  \
# 0   http://books.toscrape.com/media/cache/2c/da/2c...      3    60.0  51.77
# 1   http://books.toscrape.com/media/cache/26/0c/26...      1    20.0  53.74
# 2   http://books.toscrape.com/media/cache/3e/ef/3e...      1    20.0  50.10
# 3   http://books.toscrape.com/media/cache/32/51/32...      4    80.0  47.82
# 4   http://books.toscrape.com/media/cache/be/a5/be...      5   100.0  54.23
# 5   http://books.toscrape.com/media/cache/68/33/68...      1    20.0  22.65
# 6   http://books.toscrape.com/media/cache/92/27/92...      4    80.0  33.34
# 7   http://books.toscrape.com/media/cache/3d/54/3d...      3    60.0  17.93
# 8   http://books.toscrape.com/media/cache/66/88/66...      4    80.0  22.60
# 9   http://books.toscrape.com/media/cache/58/46/58...      1    20.0  52.15
# 10  http://books.toscrape.com/media/cache/be/f4/be...      2    40.0  13.99
# 11  http://books.toscrape.com/media/cache/10/48/10...      4    80.0  20.66
# 12  http://books.toscrape.com/media/cache/5b/88/5b...      5   100.0  17.46
# 13  http://books.toscrape.com/media/cache/94/b1/94...      5   100.0  52.29
# 14  http://books.toscrape.com/media/cache/81/c4/81...      5   100.0  35.02
# 15  http://books.toscrape.com/media/cache/54/60/54...      3    60.0  57.25
# 16  http://books.toscrape.com/media/cache/55/33/55...      1    20.0  23.88
# 17  http://books.toscrape.com/media/cache/09/a3/09...      1    20.0  37.59
# 18  http://books.toscrape.com/media/cache/0b/bc/0b...      2    40.0  51.33
# 19  http://books.toscrape.com/media/cache/27/a5/27...      2    40.0  45.17
#
#       status  is_availble
# 0   In stock         True
# 1   In stock         True
# 2   In stock         True
# 3   In stock         True
# 4   In stock         True
# 5   In stock         True
# 6   In stock         True
# 7   In stock         True
# 8   In stock         True
# 9   In stock         True
# 10  In stock         True
# 11  In stock         True
# 12  In stock         True
# 13  In stock         True
# 14  In stock         True
# 15  In stock         True
# 16  In stock         True
# 17  In stock         True
# 18  In stock         True
# 19  In stock         True
